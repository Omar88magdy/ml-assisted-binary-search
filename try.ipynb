# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_pickle("hybrid.pkl")

# %%
df["saved_runs"].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>
